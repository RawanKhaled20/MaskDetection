# %% [markdown]
# # **Importing the libraries**

# %%
import numpy as np 
import pandas as pd 
import os
import tensorflow as tf

from glob import glob
from tqdm import tqdm

import matplotlib.pyplot as plt
from PIL import Image

# %% [markdown]
# # **Loading the Images**

# %%
X_train = []
Y_train = []

for i in tqdm(glob('/kaggle/input/face-mask-detection/Dataset/mask_weared_incorrect/*')):
    temp = np.array(Image.open(i).resize((48,48)))
    X_train.append(temp)
    Y_train.append([1,0,0])
    
for i in tqdm(glob('/kaggle/input/face-mask-detection/Dataset/with_mask/*')):
    temp = np.array(Image.open(i).resize((48,48)))
    X_train.append(temp)
    Y_train.append([0,1,0])   
    
for i in tqdm(glob('/kaggle/input/face-mask-detection/Dataset/without_mask/*')):
    temp = np.array(Image.open(i).resize((48,48)))
    X_train.append(temp)
    Y_train.append([0,0,1])
# Out:
# 100%|██████████| 2994/2994 [00:06<00:00, 459.70it/s]
# 100%|██████████| 2994/2994 [00:06<00:00, 445.71it/s]
# 100%|██████████| 2994/2994 [00:06<00:00, 442.99it/s]

# %% [markdown]
# # **Normalizing the images (with any algorithm)**

# %%
X_train = np.array(X_train)
X_train = X_train/255.0
Y_train = np.array(Y_train)

# %% [markdown]
# # **Normalizing the images using Min-Max Scaling algorithm**

# %%
#X = (np.array(X) - np.min(X)) / (np.max(X) - np.min(X))
#X = X/255.0
#Y = (np.array(Y) - np.min(Y)) / (np.max(Y) - np.min(Y))

# %% [markdown]
# # **Normalizing the images using Z-Score algorithm**

# %%
# 'X = (np.array(X) - np.mean(X)) / np.std(X)
# X = X/255.0
# Y = (np.array(Y) - np.mean(Y)) / np.std(Y)'

# %% [markdown]
# # Expanding the dimensions of array (numpy)

# %% [markdown]
# # Spliting the dataset into training and testing data

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X_train, Y_train, test_size=0.2, random_state=42)

# %% [markdown]
# # CNN Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, BatchNormalization

# Define the model
model = Sequential(name='DCNN')

model.add(
    Conv2D(
        filters=64,
        kernel_size=(5,5),
        input_shape=(48, 48, 3),
        activation='elu',
        padding='same',
        kernel_initializer='he_normal',
        name='conv2d_1'
    )
)
model.add(BatchNormalization(name='batchnorm_1'))
model.add(
    Conv2D(
        filters=64,
        kernel_size=(5,5),
        activation='elu',
        padding='same',
        kernel_initializer='he_normal',
        name='conv2d_2'
    )
)
model.add(BatchNormalization(name='batchnorm_2'))

model.add(MaxPooling2D(pool_size=(2,2), name='maxpool2d_1'))
model.add(Dropout(0.4, name='dropout_1'))

model.add(
    Conv2D(
        filters=128,
        kernel_size=(3,3),
        activation='elu',
        padding='same',
        kernel_initializer='he_normal',
        name='conv2d_3'
    )
)
model.add(BatchNormalization(name='batchnorm_3'))
model.add(
    Conv2D(
        filters=128,
        kernel_size=(3,3),
        activation='elu',
        padding='same',
        kernel_initializer='he_normal',
        name='conv2d_4'
    )
)
model.add(BatchNormalization(name='batchnorm_4'))

model.add(MaxPooling2D(pool_size=(2,2), name='maxpool2d_2'))
model.add(Dropout(0.4, name='dropout_2'))

model.add(
    Conv2D(
        filters=256,
        kernel_size=(3,3),
        activation='elu',
        padding='same',
        kernel_initializer='he_normal',
        name='conv2d_5'
    )
)
model.add(BatchNormalization(name='batchnorm_5'))
model.add(
    Conv2D(
        filters=256,
        kernel_size=(3,3),
        activation='elu',
        padding='same',
        kernel_initializer='he_normal',
        name='conv2d_6'
    )
)
model.add(BatchNormalization(name='batchnorm_6'))

model.add(MaxPooling2D(pool_size=(2,2), name='maxpool2d_3'))
model.add(Dropout(0.5, name='dropout_3'))

model.add(Flatten(name='flatten'))

model.add(
    Dense(
        128,
        activation='elu',
        kernel_initializer='he_normal',
        name='dense_1'
    )
)
model.add(BatchNormalization(name='batchnorm_7'))

model.add(Dropout(0.6, name='dropout_4'))

model.add(
    Dense(
        3,
        activation='softmax',
        name='out_layer'
    )
)

model.summary()
# Out:
# Model: "DCNN"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_1 (Conv2D)           (None, 48, 48, 64)        4864
#
#  batchnorm_1 (BatchNormaliza  (None, 48, 48, 64)       256
#  tion)
#
#  conv2d_2 (Conv2D)           (None, 48, 48, 64)        102464
#
#  batchnorm_2 (BatchNormaliza  (None, 48, 48, 64)       256
#  tion)
#
#  maxpool2d_1 (MaxPooling2D)  (None, 24, 24, 64)        0
#
#  dropout_1 (Dropout)         (None, 24, 24, 64)        0
#
#  conv2d_3 (Conv2D)           (None, 24, 24, 128)       73856
#
#  batchnorm_3 (BatchNormaliza  (None, 24, 24, 128)      512
#  tion)
#
#  conv2d_4 (Conv2D)           (None, 24, 24, 128)       147584
#
#  batchnorm_4 (BatchNormaliza  (None, 24, 24, 128)      512
#  tion)
#
#  maxpool2d_2 (MaxPooling2D)  (None, 12, 12, 128)       0
#
#  dropout_2 (Dropout)         (None, 12, 12, 128)       0
#
#  conv2d_5 (Conv2D)           (None, 12, 12, 256)       295168
#
#  batchnorm_5 (BatchNormaliza  (None, 12, 12, 256)      1024
#  tion)
#
#  conv2d_6 (Conv2D)           (None, 12, 12, 256)       590080
#
#  batchnorm_6 (BatchNormaliza  (None, 12, 12, 256)      1024
#  tion)
#
#  maxpool2d_3 (MaxPooling2D)  (None, 6, 6, 256)         0
#
#  dropout_3 (Dropout)         (None, 6, 6, 256)         0
#
#  flatten (Flatten)           (None, 9216)              0
#
#  dense_1 (Dense)             (None, 128)               1179776
#
#  batchnorm_7 (BatchNormaliza  (None, 128)              512
#  tion)
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  out_layer (Dense)           (None, 3)                 387
#
# =================================================================
# Total params: 2,398,275
# Trainable params: 2,396,227
# Non-trainable params: 2,048
# _________________________________________________________________

# %% [markdown]
# # Compiling the Model

# %%
model.compile(loss='categorical_crossentropy',optimizer='Nadam', metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator

early_stopping = EarlyStopping(
    monitor='val_accuracy',
    min_delta=0.00005,
    patience=11,
    verbose=1,
    restore_best_weights=True,
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_accuracy',
    factor=0.5,
    patience=7,
    min_lr=1e-7,
    verbose=1,
)

callbacks = [
    early_stopping,
    lr_scheduler,
]

# %%
# As the data in hand is less as compared to the task so ImageDataGenerator is good to go.
train_datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.15,
    height_shift_range=0.15,
    shear_range=0.15,
    zoom_range=0.15,
    horizontal_flip=True,
)
train_datagen.fit(x_train)

# %% [markdown]
# # Training of the Model

# %%
batch_size = 32 #batch size of 32 performs the best.
epochs = 100

history = model.fit_generator(
    train_datagen.flow(x_train, y_train, batch_size=batch_size),
    validation_data=(x_test, y_test),
    steps_per_epoch=len(x_train) / batch_size,
    epochs=epochs,
    callbacks=callbacks,
    use_multiprocessing=True
)
# Out:
# Epoch 1/100
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   # Remove the CWD from sys.path while we load stuff.
# 2024-02-01 16:13:34.371897: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inDCNN/dropout_1/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 224/224 [==============================] - 15s 38ms/step - loss: 0.5604 - accuracy: 0.8134 - val_loss: 0.9373 - val_accuracy: 0.7117 - lr: 0.0010
# Epoch 2/100
# 224/224 [==============================] - 8s 34ms/step - loss: 0.3267 - accuracy: 0.8838 - val_loss: 0.2204 - val_accuracy: 0.9310 - lr: 0.0010
# Epoch 3/100
# 224/224 [==============================] - 8s 34ms/step - loss: 0
100
# 224/224 [==============================] - 8s 33ms/step - loss: 0.0563 - accuracy: 0.9793 - val_loss: 0.0435 - val_accuracy: 0.9889 - lr: 0.0010
# Epoch 32/100
# 225/224 [==============================] - ETA: 0s - loss: 0.0551 - accuracy: 0.9837
# Epoch 32: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 224/224 [==============================] - 8s 35ms/step - loss: 0.0551 - accuracy: 0.9837 - val_loss: 0.0300 - val_accuracy: 0.9911 - lr: 0.0010
# Epoch 33/100
# 224/224 [==============================] - 8s 33ms/step - loss: 0.0391 - accuracy: 0.9866 - val_loss: 0.0232 - val_accuracy: 0.9933 - lr: 5.0000e-04
# Epoch 34/100
# 224/224 [==============================] - 8s 34ms/step - loss: 0.0335 - accuracy: 0.9890 - val_loss: 0.0287 - val_accuracy: 0.9939 - lr: 5.0000e-04
# Epoch 35/100
# 224/224 [==============================] - 8s 33ms/step - loss: 0.0324 - accuracy: 0.9907 - val_loss: 0.0406 - val_accuracy: 0.9905 - lr: 5.0000e-04
# Epoch 36/100
# 224/224 [==============================] - 8s 34ms/step - loss: 0.0329 - accuracy: 0.9896 - val_loss: 0.0343 - val_accuracy: 0.9928 - lr: 5.0000e-04
# Epoch 37/100
# 224/224 [==============================] - 8s 34ms/step - loss: 0.0253 - accuracy: 0.9919 - val_loss: 0.0373 - val_accuracy: 0.9905 - lr: 5.0000e-04
# Epoch 38/100
# 224/224 [==============================] - 8s 33ms/step - loss: 0.0257 - accuracy: 0.9923 - val_loss: 0.0293 - val_accuracy: 0.9939 - lr: 5.0000e-04
# Epoch 39/100
# 224/224 [==============================] - 8s 34ms/step - loss: 0.0254 - accuracy: 0.9922 - val_loss: 0.0244 - val_accuracy: 0.9933 - lr: 5.0000e-04
# Epoch 40/100
# 224/224 [==============================] - 8s 34ms/step - loss: 0.0229 - accuracy: 0.9928 - val_loss: 0.0303 - val_accuracy: 0.9928 - lr: 5.0000e-04
# Epoch 41/100
# 225/224 [==============================] - ETA: 0s - loss: 0.0286 - accuracy: 0.9912
# Epoch 41: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 224/224 [==============================] - 8s 34ms/step - loss: 0.0286 - accuracy: 0.9912 - val_loss: 0.0370 - val_accuracy: 0.9900 - lr: 5.0000e-04
# Epoch 42/100
# 224/224 [==============================] - 8s 34ms/step - loss: 0.0242 - accuracy: 0.9928 - val_loss: 0.0197 - val_accuracy: 0.9944 - lr: 2.5000e-04
# Epoch 43/100
# 224/224 [==============================] - 8s 33ms/step - loss: 0.0165 - accuracy: 0.9940 - val_loss: 0.0203 - val_accuracy: 0.9933 - lr: 2.5000e-04
# Epoch 44/100
# 224/224 [==============================] - 8s 35ms/step - loss: 0.0161 - accuracy: 0.9950 - val_loss: 0.0168 - val_accuracy: 0.9967 - lr: 2.5000e-04
# Epoch 45/100
# 224/224 [==============================] - 8s 33ms/step - loss: 0.0149 - accuracy: 0.9946 - val_loss: 0.0169 - val_accuracy: 0.9961 - lr: 2.5000e-04
# Epoch 46/100
# 224/224 [==============================] - 8s 34ms/step - loss: 0.0161 - accuracy: 0.9951 - val_loss: 0.0232 - val_accuracy: 0.9961 - lr: 2.5000e-04
# Epoch 47/100
# 224/224 [==============================] - 8s 34ms/step - loss: 0.0160 - accuracy: 0.9940 - val_loss: 0.0255 - val_accuracy: 0.9944 - lr: 2.5000e-04
# Epoch 48/100
# 224/224 [==============================] - 8s 35ms/step - loss: 0.0117 - accuracy: 0.9954 - val_loss: 0.0221 - val_accuracy: 0.9967 - lr: 2.5000e-04
# Epoch 49/100
# 224/224 [==============================] - 8s 33ms/step - loss: 0.0121 - accuracy: 0.9961 - val_loss: 0.0216 - val_accuracy: 0.9961 - lr: 2.5000e-04
# Epoch 50/100
# 224/224 [==============================] - 8s 34ms/step - loss: 0.0107 - accuracy: 0.9961 - val_loss: 0.0257 - val_accuracy: 0.9944 - lr: 2.5000e-04
# Epoch 51/100
# 225/224 [==============================] - ETA: 0s - loss: 0.0123 - accuracy: 0.9965
# Epoch 51: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 224/224 [==============================] - 8s 34ms/step - loss: 0.0123 - accuracy: 0.9965 - val_loss: 0.0279 - val_accuracy: 0.9939 - lr: 2.5000e-04
# Epoch 52/100
# 224/224 [==============================] - 8s 34ms/step - loss: 0.0093 - accuracy: 0.9972 - val_loss: 0.0218 - val_accuracy: 0.9972 - lr: 1.2500e-04
# Epoch 53/100
# 224/224 [==============================] - 8s 34ms/step - loss: 0.0125 - accuracy: 0.9964 - val_loss: 0.0226 - val_accuracy: 0.9967 - lr: 1.2500e-04
# Epoch 54/100
# 224/224 [==============================] - 8s 34ms/step - loss: 0.0055 - accuracy: 0.9986 - val_loss: 0.0206 - val_accuracy: 0.9961 - lr: 1.2500e-04
# Epoch 55/100
# 224/224 [==============================] - 8s 34ms/step - loss: 0.0136 - accuracy: 0.9961 - val_loss: 0.0217 - val_accuracy: 0.9955 - lr: 1.2500e-04
# Epoch 56/100
# 224/224 [==============================] - 8s 34ms/step - loss: 0.0108 - accuracy: 0.9955 - val_loss: 0.0251 - val_accuracy: 0.9955 - lr: 1.2500e-04
# Epoch 57/100
# 224/224 [==============================] - 8s 34ms/step - loss: 0.0120 - accuracy: 0.9965 - val_loss: 0.0299 - val_accuracy: 0.9933 - lr: 1.2500e-04
# Epoch 58/100
# 224/224 [==============================] - 8s 33ms/step - loss: 0.0119 - accuracy: 0.9965 - val_loss: 0.0261 - val_accuracy: 0.9955 - lr: 1.2500e-04
# Epoch 59/100
# 225/224 [==============================] - ETA: 0s - loss: 0.0073 - accuracy: 0.9981
# Epoch 59: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 224/224 [==============================] - 8s 34ms/step - loss: 0.0073 - accuracy: 0.9981 - val_loss: 0.0217 - val_accuracy: 0.9944 - lr: 1.2500e-04
# Epoch 60/100
# 224/224 [==============================] - 8s 34ms/step - loss: 0.0098 - accuracy: 0.9971 - val_loss: 0.0223 - val_accuracy: 0.9961 - lr: 6.2500e-05
# Epoch 61/100
# 224/224 [==============================] - 8s 34ms/step - loss: 0.0072 - accuracy: 0.9979 - val_loss: 0.0261 - val_accuracy: 0.9950 - lr: 6.2500e-05
# Epoch 62/100
# 224/224 [==============================] - 8s 34ms/step - loss: 0.0064 - accuracy: 0.9978 - val_loss: 0.0228 - val_accuracy: 0.9955 - lr: 6.2500e-05
# Epoch 63/100
# 225/224 [==============================] - ETA: 0s - loss: 0.0077 - accuracy: 0.9972Restoring model weights from the end of the best epoch: 52.
# 224/224 [==============================] - 8s 34ms/step - loss: 0.0077 - accuracy: 0.9972 - val_loss: 0.0218 - val_accuracy: 0.9967 - lr: 6.2500e-05
# Epoch 63: early stopping

# %% [markdown]
# # Model Evaluation

# %%
model.evaluate(x_test, y_test)
# Out:
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0218 - accuracy: 0.9972
# [0.02180853858590126, 0.99721759557724]

# %% [markdown]
# # Loading the Model Performance

# %%
from keras.models import load_model
best_model = load_model('/kaggle/working/bestModel.h5')
best_model.evaluate(x_test, y_test)

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Loop through the first 5 images in x_test
for i in x_test[12:18]:
    # Resize the image to 48x48 pixels
    i_resized = cv2.resize(i, (48, 48))

    # Expand dimensions to add batch dimension
    i_expanded = np.expand_dims(i_resized, axis=0)

    # Perform prediction
    result = model.predict(i_expanded)
    result=np.argmax(result)

    # Plot the image
    plt.imshow(i_resized)
    plt.show()

    # Perform action based on prediction result
    if result == 0:
        print('Mask weared incorrect')
    elif result==1 :
        print("Mask")
    else:
        print("No mask")
# Out:
# 1/1 [==============================] - 0s 180ms/step
# No mask
# 1/1 [==============================] - 0s 23ms/step
# Mask weared incorrect
# 1/1 [==============================] - 0s 22ms/step
# Mask
# 1/1 [==============================] - 0s 21ms/step
# Mask
# 1/1 [==============================] - 0s 20ms/step
# No mask
# 1/1 [==============================] - 0s 21ms/step
# Mask weared incorrect

# %% [markdown]
# # Changing the dimensions and Plotting the trained images

# %%
import cv2
import numpy as np

# Load the image
img_path = '/kaggle/input/covid-face-mask-detection-dataset/New Masks Dataset/Train/Non Mask/11.jpg'
img = cv2.imread(img_path)

# Resize the image to 48x48 pixels
img_resized = cv2.resize(img, (48, 48))

# Convert the image to RGB (assuming it's in BGR format)
img_rgb = cv2.cvtColor(img_resized, cv2.COLOR_BGR2RGB)

# Normalize the pixel values to the range [0, 1]
img_normalized = img_rgb / 255.0

# Add batch dimension to the image
img_with_batch = np.expand_dims(img_normalized, axis=0)

# Perform prediction using the image with batch dimension
result = model.predict(img_with_batch)
result=np.argmax(result)

# Perform action based on prediction result
if result == 0:
        print('Mask weared incorrect')
elif result==1 :
        print("Mask")
else:
        print("No mask")
# Out:
# 1/1 [==============================] - 0s 21ms/step
# No mask

# %%
model.save('Masks2.h5')

# %% [markdown]
# # Prediction and Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

plt.figure(figsize=(15, 5))

preds = model.predict(x_test)
preds = (preds >= 0.5).astype(np.int32)
cm = confusion_matrix(y_test, preds)
df_cm = pd.DataFrame(cm, index=['closed', 'Open'], columns=['Closed', 'Open'])
plt.subplot(121)
plt.title("Confusion matrix\n")
sns.heatmap(df_cm, annot=True, fmt="d", cmap="YlGnBu")
plt.ylabel("Predicted")
plt.xlabel("Actual")

# %% [markdown]
# # Accuracy
#
# Evaluating the Accuracy

# %%
accuracy = best_model.evaluate(x_test, y_test)[1]
print("Accuracy:", accuracy)
